# %% [markdown]
# # container types intro

# %% [markdown]
# * list
# * tuple
# * dictionary
# * set

# %%
fruits = ["apple","banana","cherry"]
type(fruits)
# Out:
# list

# %%
numbers = [1,2,3,4,5,6]
print (numbers)
type(numbers)
# Out:
# [1, 2, 3, 4, 5, 6]
# list

# %%
mixed = ["apple", 1 ,True]
print(mixed)
# Out:
# ['apple', 1, True]

# %%
print(list("abcd"))
# Out:
# ['a', 'b', 'c', 'd']
