# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\sarvinoz\appdata\local\programs\python\python313\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sarvinoz\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sarvinoz\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sarvinoz\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sarvinoz\appdata\local\programs\python\python313\lib\site-packages (from requests) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install beautifulsoup4
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001B6EFC99160>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/beautifulsoup4/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001B6EFC560D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/beautifulsoup4/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001B6EFC56350>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/beautifulsoup4/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001B6EFC565D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/beautifulsoup4/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000001B6EFC56850>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/beautifulsoup4/
# ERROR: Could not find a version that satisfies the requirement beautifulsoup4 (from versions: none)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for beautifulsoup4

# %%
python.exe -m pip install --upgrade pip
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 python.exe
#
# NameError: name 'python' is not defined

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(html_doc, "html.parser")
print(soup.prettify())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from bs4 import BeautifulSoup
#       2 soup=BeautifulSoup(html_doc, "html.parser")
#       3 print(soup.prettify())
#
# ModuleNotFoundError: No module named 'bs4'
