# %%
a = int(input("please enter any number to check if it is even or odd: "))
print(a)
if a % 2==0:
    print("it is even")
else:
    print("it is odd")
# Out:
# 6
# it is even

# %%
text=input("input 3 number with ',' in order to split")
numbers=[int(x)for x in text.split(",")]
max_number=max(numbers)
print(max_number)
# Out:
# 9

# %%
a=int(input("please enter your score in order ot know your level"))
if a>100 or a<0:
    print("sorry,there is no such score. please enter your actual score")
elif a>=90 and a<=100:
    print("Super, your level is 'A'")
elif a>=80 and a<=89:
    print("your level is 'B'")
elif a>=70 and a<=79:
    print("your level is 'C'")
elif a>=60 and a>=69:
    print("your level is 'D'")
else :
    print("your score is too low and you failed")
# Out:
# sorry,there is no such score. please enter your actual score

# %%
a=int(input("please enter  any number that you want to kmow the sum of all previus numbers "))
sum_of_numbers=a*(a+1)//2
print(sum_of_numbers)
# Out:
# 45

# %%
a=int(input("please enter  any number that you want to kmow the sum of all previus numbers "))
sum_numbers=0
for i in range(1,a+1):
    sum_numbers+=i
print(sum_numbers)
# Out:
# 45

# %%
password=input("please enter strong password that contains at least 8 characters with at least 1 number")
if len(password)>=8 and any(p.isdigit() for p in password):
    print("your password is strong")
else:
    print("your password is weak")
# Out:
# your password is weak

# %%
password=input("please enter strong password that contains at least 8 characters with at least 1 number")
a=(len(password)>=8)
if any(i.isdigit for i in password):
    print("true")
else:
    print("false")
# Out:
# False
# True
