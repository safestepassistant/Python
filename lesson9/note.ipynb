# %%
from __future__ import annotations
from datetime import datetime

class note:
    def __init__(self, id: int ,text:str ,created_time:datetime):
        self.id=id
        self.text=text
        self.created_time=created_time

    
    @classmethod
    def from_dic(cls,values:dict[str,str]):
        note_id=values['id']
        text=values['text']
        created_date=values['create_date']
        return cls(note_id, text, created_date) 
    
    @classmethod
    def from_tuple(cls,values:tuple[str,str,str]):
        pass
    def as_dict(self)->dict[str,str]:
        pass
    def as_dict(self)->tuple[str,str,str]:
        pass
    def __str__(self):
        return f'Note(id={self.id}, text="{self.text}", created_time="{self.created_time}")'
# Out:
# 2026-02-05 00:35:57.724932

# %%
# %pip install requests
# Out:
# ...
#
#    ---------------------------------------- 0/5 [urllib3]
#    ---------------- ----------------------- 2/5 [charset_normalizer]
#    -------------------------------- ------- 4/5 [requests]
#    ---------------------------------------- 5/5 [requests]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests

# %%
requests.get("https://example.com")
# Out:
# <Response [200]>

# %%
res=requests.get("https://example.com")

# %%
res.status_code
# Out:
# 200
