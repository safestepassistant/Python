# %%
class CustomException(Exception):
    pass
raise CustomException("something went wrong. check it . look at your code  ")
# Out:
# ---------------------------------------------------------------------------
# CustomException                           Traceback (most recent call last)
# Cell In[1], line 3
#       1 class CustomException(Exception):
#       2     pass
# ----> 3 raise CustomException("something went wrong. check it . look at your code  ")
#
# CustomException: something went wrong. check it . look at your code

# %%
class Parent:
    def __init__(self, msg:str):
        self.msg=msg
try:
    raise CustomException("some message")
except CustomException as exc:
    print(exc.msg)
# Out:
# ---------------------------------------------------------------------------
# CustomException                           Traceback (most recent call last)
# Cell In[2], line 5
#       4 try:
# ----> 5     raise CustomException("some message")
#       6 except CustomException as exc:
#
# CustomException: some message
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 7
#       5     raise CustomException("some message")
#       6 except CustomException as exc:
# ----> 7     print(exc.msg)
#
# AttributeError: 'CustomException' object has no attribute 'msg'
