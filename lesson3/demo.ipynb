# %% [markdown]
# ## dictionary

# %%
user_dic = {
    "name": "Ali",
    "age": 20
}

key = input("enter the key to retrieve its value: ")
value = user_dic.get(key, "key not found")
print(f"value for {key}: {value}")

# %%
print("end of an application")
# Out:
# end of an application
